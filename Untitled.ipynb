# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = pd.read_csv("Data-Science-for-COVID-19-master\dataset\Patient\PatientInfo.csv")

# %%
newData = data.groupby(['confirmed_date', 'infection_case' ]).count()['patient_id']
fig, ax = plt.subplots(figsize=(27,7))
data.groupby(['confirmed_date', 'infection_case' ]).count()['patient_id'].unstack().plot(ax=ax)
