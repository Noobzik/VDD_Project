# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

pd.read_csv("Data-Science-for-COVID-19-master\dataset\Patient\PatientInfo.csv")
# Out:
#       patient_id  global_num     sex  birth_year  age country province  \
# 0     1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1     1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2     1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3     1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4     1000000005         9.0  female      1992.0  20s   Korea    Seoul
# ...          ...         ...     ...         ...  ...     ...      ...
# 3514  7000000010         NaN  female         NaN  20s   Korea  Jeju-do
# 3515  7000000011         NaN    male         NaN  30s   Korea  Jeju-do
# 3516  7000000012         NaN  female         NaN  20s   Korea  Jeju-do
# 3517  7000000013         NaN  female         NaN  10s   China  Jeju-do
# 3518  7000000014         NaN  female         NaN  30s   Korea  Jeju-do
#
#              city disease        infection_case  infection_order  \
# ...

# %%
data.groupby('confirmed_date')
